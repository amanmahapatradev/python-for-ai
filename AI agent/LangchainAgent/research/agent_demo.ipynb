# %%
import os
import certifi
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain import hub
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 7
#       3 from dotenv import load_dotenv
#       4
#       5 from langchain_openai import ChatOpenAI
#       6 from langchain_community.tools.tavily_search import TavilySearchResults
# ----> 7 from langchain import hub
#       8 from langchain.agents import create_tool_calling_agent, AgentExecutor
#
# ImportError: cannot import name 'hub' from 'langchain' (e:\AI agent\python-ai-agent\.venv\Lib\site-packages\langchain\__init__.py)
